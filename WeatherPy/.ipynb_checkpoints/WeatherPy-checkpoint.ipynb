# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Url and units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# Loop through the list of cities and perform a request for data on each
print("Beginning Data Retrieval")
print("--------------------------------------------")
count = 0
set = 1
for idx, city in enumerate(cities):
    count = count + 1
    # To avoid api call rate limits, get city weather data for 50 cities,
    # then sleep for 5 seconds, and then continue with next 50 cities and so on...
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
print("------------------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | margate
# Processing Record 3 of Set 1 | bermeo
# Processing Record 4 of Set 1 | kruisfontein
# Processing Record 5 of Set 1 | sao filipe
# Processing Record 6 of Set 1 | tevaitoa
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | svetlyy
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | waipawa
# Processing Record 14 of Set 1 | farrukhnagar
# Processing Record 15 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | lata
# Processing Record 17 of Set 1 | caucasia
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | panaba
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | qaqortoq
# Processing Record 27 of Set 1 | amapa
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | taltal
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | whitehorse
# Processing Record 33 of Set 1 | kargil
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | florianopolis
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | callaguip
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | zhanaozen
# Processing Record 46 of Set 1 | airai
# Processing Record 47 of Set 1 | huicungo
# Processing Record 48 of Set 1 | itarema
# Processing Record 49 of Set 1 | talnakh
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | port-gentil
# Processing Record 2 of Set 2 | chenghai
# Processing Record 3 of Set 2 | alofi
# Processing Record 4 of Set 2 | shalinskoye
# Processing Record 5 of Set 2 | sindand
# City not found. Skipping...
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | snyder
# Processing Record 8 of Set 2 | tautira
# Processing Record 9 of Set 2 | yar-sale
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | aksha
# Processing Record 12 of Set 2 | isangel
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | kudahuvadhoo
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | sao jose da coroa grande
# Processing Record 17 of Set 2 | santa barbara
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | mbekenyera
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | te anau
# Processing Record 27 of Set 2 | les cayes
# Processing Record 28 of Set 2 | sao geraldo do araguaia
# Processing Record 29 of Set 2 | hirara
# Processing Record 30 of Set 2 | nanortalik
# Processing Record 31 of Set 2 | bulgan
# Processing Record 32 of Set 2 | mehamn
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | vila franca do campo
# Processing Record 37 of Set 2 | san jose
# Processing Record 38 of Set 2 | phangnga
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | albany
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | namibe
# Processing Record 43 of Set 2 | vila
# Processing Record 44 of Set 2 | machico
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | aklavik
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | comodoro rivadavia
# Processing Record 49 of Set 2 | tubuala
# Processing Record 50 of Set 2 | pangnirtung
# Processing Record 1 of Set 3 | ayan
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | ostrovnoy
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | haines junction
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | pimentel
# Processing Record 8 of Set 3 | saint george
# Processing Record 9 of Set 3 | moron
# Processing Record 10 of Set 3 | solwezi
# Processing Record 11 of Set 3 | poum
# Processing Record 12 of Set 3 | riyadh
# Processing Record 13 of Set 3 | grand gaube
# Processing Record 14 of Set 3 | ondjiva
# Processing Record 15 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 3 | otane
# Processing Record 17 of Set 3 | brae
# Processing Record 18 of Set 3 | palmer
# Processing Record 19 of Set 3 | tete
# Processing Record 20 of Set 3 | arlit
# Processing Record 21 of Set 3 | hobyo
# Processing Record 22 of Set 3 | port moresby
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | luena
# Processing Record 25 of Set 3 | tateyama
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | wasilla
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | teguldet
# Processing Record 30 of Set 3 | port lincoln
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | mufumbwe
# Processing Record 33 of Set 3 | barrow
# Processing Record 34 of Set 3 | doha
# Processing Record 35 of Set 3 | sitka
# Processing Record 36 of Set 3 | kyabe
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | aykhal
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | milos
# Processing Record 41 of Set 3 | llata
# Processing Record 42 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 3 | hobart
# Processing Record 44 of Set 3 | quixeramobim
# Processing Record 45 of Set 3 | svetlaya
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | acari
# Processing Record 48 of Set 3 | penzance
# Processing Record 49 of Set 3 | port elizabeth
# Processing Record 50 of Set 3 | batagay-alyta
# Processing Record 1 of Set 4 | galdar
# Processing Record 2 of Set 4 | belaya gora
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | sokoni
# Processing Record 5 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 4 | lompoc
# Processing Record 7 of Set 4 | aksarka
# Processing Record 8 of Set 4 | goderich
# Processing Record 9 of Set 4 | nadvoitsy
# Processing Record 10 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | upernavik
# Processing Record 14 of Set 4 | tibati
# Processing Record 15 of Set 4 | carmen
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | portland
# Processing Record 18 of Set 4 | keffi
# Processing Record 19 of Set 4 | kota kinabalu
# Processing Record 20 of Set 4 | tiznit
# Processing Record 21 of Set 4 | ulladulla
# Processing Record 22 of Set 4 | new norfolk
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | manzil jamil
# City not found. Skipping...
# Processing Record 25 of Set 4 | ayorou
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | chau doc
# Processing Record 28 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 4 | pampa
# Processing Record 30 of Set 4 | hornepayne
# Processing Record 31 of Set 4 | cape coast
# Processing Record 32 of Set 4 | karratha
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | mahajanga
# Processing Record 35 of Set 4 | kanlagay
# Processing Record 36 of Set 4 | tirumullaivasal
# Processing Record 37 of Set 4 | vyartsilya
# Processing Record 38 of Set 4 | hambantota
# Processing Record 39 of Set 4 | kaz
# Processing Record 40 of Set 4 | kholodnyy
# Processing Record 41 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 4 | sao joao da barra
# Processing Record 43 of Set 4 | bourg-les-valence
# Processing Record 44 of Set 4 | deputatskiy
# Processing Record 45 of Set 4 | santa isabel
# Processing Record 46 of Set 4 | dalbandin
# Processing Record 47 of Set 4 | yatsushiro
# Processing Record 48 of Set 4 | mahebourg
# Processing Record 49 of Set 4 | zaton
# Processing Record 50 of Set 4 | ajdabiya
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | vostok
# Processing Record 3 of Set 5 | rawson
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | kerema
# Processing Record 7 of Set 5 | podgornoye
# Processing Record 8 of Set 5 | dali
# Processing Record 9 of Set 5 | richards bay
# Processing Record 10 of Set 5 | nizhnyaya tavda
# Processing Record 11 of Set 5 | cam ranh
# Processing Record 12 of Set 5 | saint anthony
# Processing Record 13 of Set 5 | gobabis
# Processing Record 14 of Set 5 | hukuntsi
# Processing Record 15 of Set 5 | leningradskiy
# Processing Record 16 of Set 5 | iwamizawa
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | coquimbo
# Processing Record 19 of Set 5 | kemi
# Processing Record 20 of Set 5 | east london
# Processing Record 21 of Set 5 | kasempa
# Processing Record 22 of Set 5 | taicheng
# Processing Record 23 of Set 5 | sainte-thecle
# Processing Record 24 of Set 5 | marawi
# Processing Record 25 of Set 5 | maputo
# Processing Record 26 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 5 | tuktoyaktuk
# Processing Record 28 of Set 5 | padang
# Processing Record 29 of Set 5 | kolondieba
# Processing Record 30 of Set 5 | mocoa
# Processing Record 31 of Set 5 | hasaki
# Processing Record 32 of Set 5 | smithers
# Processing Record 33 of Set 5 | roebourne
# Processing Record 34 of Set 5 | ponta delgada
# Processing Record 35 of Set 5 | moose factory
# Processing Record 36 of Set 5 | kiunga
# Processing Record 37 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 5 | skara
# Processing Record 39 of Set 5 | chingirlau
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | waingapu
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | hervey bay
# Processing Record 44 of Set 5 | yefira
# City not found. Skipping...
# Processing Record 45 of Set 5 | marsh harbour
# Processing Record 46 of Set 5 | lasa
# Processing Record 47 of Set 5 | yenagoa
# Processing Record 48 of Set 5 | cap malheureux
# Processing Record 49 of Set 5 | wahiawa
# Processing Record 50 of Set 5 | scottsboro
# Processing Record 1 of Set 6 | dawei
# Processing Record 2 of Set 6 | susangerd
# Processing Record 3 of Set 6 | yongan
# Processing Record 4 of Set 6 | plettenberg bay
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | boyolangu
# Processing Record 7 of Set 6 | olafsvik
# Processing Record 8 of Set 6 | chokurdakh
# Processing Record 9 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 6 | saint-louis
# Processing Record 11 of Set 6 | sikea
# City not found. Skipping...
# Processing Record 12 of Set 6 | birin
# Processing Record 13 of Set 6 | laguna
# Processing Record 14 of Set 6 | kungurtug
# Processing Record 15 of Set 6 | toktogul
# Processing Record 16 of Set 6 | kavaratti
# Processing Record 17 of Set 6 | opobo
# City not found. Skipping...
# Processing Record 18 of Set 6 | cherskiy
# Processing Record 19 of Set 6 | dunedin
# Processing Record 20 of Set 6 | amuntai
# Processing Record 21 of Set 6 | khandwa
# Processing Record 22 of Set 6 | san quintin
# Processing Record 23 of Set 6 | varhaug
# Processing Record 24 of Set 6 | sawtell
# Processing Record 25 of Set 6 | okhotsk
# Processing Record 26 of Set 6 | lyaskelya
# Processing Record 27 of Set 6 | tatarsk
# Processing Record 28 of Set 6 | kangalassy
# Processing Record 29 of Set 6 | shakawe
# Processing Record 30 of Set 6 | matay
# Processing Record 31 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 6 | dahra
# Processing Record 33 of Set 6 | abong mbang
# Processing Record 34 of Set 6 | saint-francois
# Processing Record 35 of Set 6 | severnoye
# Processing Record 36 of Set 6 | umm lajj
# Processing Record 37 of Set 6 | catio
# Processing Record 38 of Set 6 | mackenzie
# Processing Record 39 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 40 of Set 6 | acarau
# Processing Record 41 of Set 6 | popondetta
# Processing Record 42 of Set 6 | ngunguru
# Processing Record 43 of Set 6 | bandar-e anzali
# Processing Record 44 of Set 6 | chuy
# Processing Record 45 of Set 6 | husavik
# Processing Record 46 of Set 6 | qui nhon
# Processing Record 47 of Set 6 | derzhavinsk
# Processing Record 48 of Set 6 | okha
# Processing Record 49 of Set 6 | kelowna
# Processing Record 50 of Set 6 | broome
# Processing Record 1 of Set 7 | greencastle
# Processing Record 2 of Set 7 | launceston
# Processing Record 3 of Set 7 | helong
# Processing Record 4 of Set 7 | hay river
# Processing Record 5 of Set 7 | faanui
# Processing Record 6 of Set 7 | wanning
# Processing Record 7 of Set 7 | alta
# Processing Record 8 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 7 | faya
# Processing Record 10 of Set 7 | pinawa
# Processing Record 11 of Set 7 | huambo
# Processing Record 12 of Set 7 | mahibadhoo
# Processing Record 13 of Set 7 | tall kayf
# Processing Record 14 of Set 7 | half moon bay
# Processing Record 15 of Set 7 | yinchuan
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | bonthe
# Processing Record 18 of Set 7 | hvide sande
# Processing Record 19 of Set 7 | maarianhamina
# Processing Record 20 of Set 7 | dicabisagan
# Processing Record 21 of Set 7 | mumbwa
# Processing Record 22 of Set 7 | uarini
# Processing Record 23 of Set 7 | kalmunai
# Processing Record 24 of Set 7 | klyuchi
# Processing Record 25 of Set 7 | velyka mykhaylivka
# Processing Record 26 of Set 7 | owensboro
# Processing Record 27 of Set 7 | horta
# Processing Record 28 of Set 7 | eregli
# Processing Record 29 of Set 7 | alta floresta
# Processing Record 30 of Set 7 | hadejia
# Processing Record 31 of Set 7 | gladstone
# Processing Record 32 of Set 7 | vernon
# Processing Record 33 of Set 7 | la montanita
# Processing Record 34 of Set 7 | conde
# Processing Record 35 of Set 7 | deyang
# Processing Record 36 of Set 7 | gibsons
# Processing Record 37 of Set 7 | buenaventura
# Processing Record 38 of Set 7 | muros
# Processing Record 39 of Set 7 | rorvik
# Processing Record 40 of Set 7 | bolivar
# Processing Record 41 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 42 of Set 7 | thornaby
# Processing Record 43 of Set 7 | kupang
# Processing Record 44 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | norman wells
# Processing Record 46 of Set 7 | poya
# Processing Record 47 of Set 7 | burica
# City not found. Skipping...
# Processing Record 48 of Set 7 | bathsheba
# Processing Record 49 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 7 | matara
# Processing Record 1 of Set 8 | wau
# Processing Record 2 of Set 8 | mikuni
# Processing Record 3 of Set 8 | alyangula
# Processing Record 4 of Set 8 | ahipara
# Processing Record 5 of Set 8 | mbalmayo
# Processing Record 6 of Set 8 | tavrichanka
# Processing Record 7 of Set 8 | clyde river
# Processing Record 8 of Set 8 | payo
# Processing Record 9 of Set 8 | coruripe
# Processing Record 10 of Set 8 | torbay
# Processing Record 11 of Set 8 | atlantic beach
# Processing Record 12 of Set 8 | zyryanka
# Processing Record 13 of Set 8 | lagoa
# Processing Record 14 of Set 8 | tual
# Processing Record 15 of Set 8 | pesochenskiy
# Processing Record 16 of Set 8 | tupik
# Processing Record 17 of Set 8 | mnogovershinnyy
# Processing Record 18 of Set 8 | kinkala
# Processing Record 19 of Set 8 | mamallapuram
# Processing Record 20 of Set 8 | klaksvik
# Processing Record 21 of Set 8 | taoudenni
# Processing Record 22 of Set 8 | ucluelet
# Processing Record 23 of Set 8 | truro
# Processing Record 24 of Set 8 | ilyich
# Processing Record 25 of Set 8 | namatanai
# Processing Record 26 of Set 8 | dok kham tai
# Processing Record 27 of Set 8 | grindavik
# Processing Record 28 of Set 8 | rio gallegos
# Processing Record 29 of Set 8 | nabire
# Processing Record 30 of Set 8 | khipro
# Processing Record 31 of Set 8 | omsukchan
# Processing Record 32 of Set 8 | potsdam
# Processing Record 33 of Set 8 | harper
# Processing Record 34 of Set 8 | vila velha
# Processing Record 35 of Set 8 | nuzvid
# Processing Record 36 of Set 8 | terrace
# Processing Record 37 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 8 | mollendo
# Processing Record 39 of Set 8 | oktyabrskoye
# Processing Record 40 of Set 8 | necochea
# Processing Record 41 of Set 8 | bar harbor
# Processing Record 42 of Set 8 | walvis bay
# Processing Record 43 of Set 8 | villa maria
# Processing Record 44 of Set 8 | buchmany
# Processing Record 45 of Set 8 | pedasi
# Processing Record 46 of Set 8 | manyana
# Processing Record 47 of Set 8 | kloulklubed
# Processing Record 48 of Set 8 | verkhniy rohachyk
# Processing Record 49 of Set 8 | calatayud
# Processing Record 50 of Set 8 | red bluff
# Processing Record 1 of Set 9 | cervo
# Processing Record 2 of Set 9 | coihaique
# Processing Record 3 of Set 9 | gatton
# Processing Record 4 of Set 9 | saldanha
# Processing Record 5 of Set 9 | beyneu
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | havelock
# Processing Record 8 of Set 9 | sao gabriel
# Processing Record 9 of Set 9 | skelleftea
# Processing Record 10 of Set 9 | sabang
# Processing Record 11 of Set 9 | kurya
# Processing Record 12 of Set 9 | bintulu
# Processing Record 13 of Set 9 | whitianga
# Processing Record 14 of Set 9 | vanimo
# Processing Record 15 of Set 9 | korla
# Processing Record 16 of Set 9 | kahului
# Processing Record 17 of Set 9 | mlowo
# Processing Record 18 of Set 9 | port hardy
# Processing Record 19 of Set 9 | marquard
# Processing Record 20 of Set 9 | talkha
# Processing Record 21 of Set 9 | honiara
# Processing Record 22 of Set 9 | saint-augustin
# Processing Record 23 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 9 | buffalo
# Processing Record 25 of Set 9 | tarauaca
# Processing Record 26 of Set 9 | asau
# Processing Record 27 of Set 9 | srandakan
# Processing Record 28 of Set 9 | uruana
# Processing Record 29 of Set 9 | adrar
# Processing Record 30 of Set 9 | brasileia
# Processing Record 31 of Set 9 | lincoln
# Processing Record 32 of Set 9 | longyearbyen
# Processing Record 33 of Set 9 | narsaq
# Processing Record 34 of Set 9 | caravelas
# Processing Record 35 of Set 9 | yaan
# Processing Record 36 of Set 9 | palana
# Processing Record 37 of Set 9 | chumikan
# Processing Record 38 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 9 | cherbourg
# Processing Record 40 of Set 9 | strezhevoy
# Processing Record 41 of Set 9 | terrace bay
# Processing Record 42 of Set 9 | preobrazheniye
# Processing Record 43 of Set 9 | abu samrah
# Processing Record 44 of Set 9 | sheltozero
# Processing Record 45 of Set 9 | baghdad
# Processing Record 46 of Set 9 | avera
# Processing Record 47 of Set 9 | pasighat
# Processing Record 48 of Set 9 | oranjemund
# Processing Record 49 of Set 9 | mutare
# Processing Record 50 of Set 9 | camana
# Processing Record 1 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 3 of Set 10 | rochester
# Processing Record 4 of Set 10 | nsanje
# Processing Record 5 of Set 10 | nyuksenitsa
# Processing Record 6 of Set 10 | santander
# Processing Record 7 of Set 10 | nelson bay
# Processing Record 8 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 10 | butiama
# Processing Record 10 of Set 10 | navalgund
# Processing Record 11 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 10 | qujing
# Processing Record 13 of Set 10 | thinadhoo
# Processing Record 14 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 16 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 10 | date
# Processing Record 18 of Set 10 | uige
# Processing Record 19 of Set 10 | denpasar
# Processing Record 20 of Set 10 | komsomolskiy
# Processing Record 21 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 10 | sechura
# Processing Record 23 of Set 10 | college
# Processing Record 24 of Set 10 | shieli
# Processing Record 25 of Set 10 | el sauzal
# Processing Record 26 of Set 10 | madimba
# Processing Record 27 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 28 of Set 10 | dingle
# Processing Record 29 of Set 10 | harbour breton
# Processing Record 30 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 31 of Set 10 | bethel
# Processing Record 32 of Set 10 | manicore
# Processing Record 33 of Set 10 | palatka
# Processing Record 34 of Set 10 | srednekolymsk
# Processing Record 35 of Set 10 | bubaque
# Processing Record 36 of Set 10 | tikrit
# Processing Record 37 of Set 10 | zhigansk
# Processing Record 38 of Set 10 | gigmoto
# Processing Record 39 of Set 10 | talcahuano
# Processing Record 40 of Set 10 | sibolga
# Processing Record 41 of Set 10 | trinidad
# Processing Record 42 of Set 10 | nome
# Processing Record 43 of Set 10 | bathurst
# Processing Record 44 of Set 10 | erken-shakhar
# City not found. Skipping...
# Processing Record 45 of Set 10 | bowen
# Processing Record 46 of Set 10 | nyzhnya duvanka
# Processing Record 47 of Set 10 | kutum
# Processing Record 48 of Set 10 | mangan
# Processing Record 49 of Set 10 | biak
# Processing Record 50 of Set 10 | grootfontein
# Processing Record 1 of Set 11 | mopipi
# Processing Record 2 of Set 11 | sao joaquim
# Processing Record 3 of Set 11 | xinpu
# Processing Record 4 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 11 | mecca
# Processing Record 6 of Set 11 | morant bay
# Processing Record 7 of Set 11 | minudasht
# Processing Record 8 of Set 11 | cradock
# Processing Record 9 of Set 11 | flinders
# Processing Record 10 of Set 11 | khuzhir
# Processing Record 11 of Set 11 | severo-kurilsk
# Processing Record 12 of Set 11 | beba
# Processing Record 13 of Set 11 | tiarei
# Processing Record 14 of Set 11 | quatre cocos
# Processing Record 15 of Set 11 | lovozero
# Processing Record 16 of Set 11 | banda aceh
# Processing Record 17 of Set 11 | kualakapuas
# Processing Record 18 of Set 11 | praia da vitoria
# Processing Record 19 of Set 11 | paragominas
# Processing Record 20 of Set 11 | cururupu
# Processing Record 21 of Set 11 | swan hill
# Processing Record 22 of Set 11 | doda
# Processing Record 23 of Set 11 | araripe
# Processing Record 24 of Set 11 | mazatlan
# Processing Record 25 of Set 11 | cuayucatepec
# City not found. Skipping...
# Processing Record 26 of Set 11 | makakilo city
# Processing Record 27 of Set 11 | amazar
# Processing Record 28 of Set 11 | pinambaran
# Processing Record 29 of Set 11 | jizan
# Processing Record 30 of Set 11 | zhuzhou
# Processing Record 31 of Set 11 | tanete
# Processing Record 32 of Set 11 | mwanza
# Processing Record 33 of Set 11 | lewiston
# Processing Record 34 of Set 11 | bogotol
# Processing Record 35 of Set 11 | nantucket
# Processing Record 36 of Set 11 | vitim
# Processing Record 37 of Set 11 | bauchi
# Processing Record 38 of Set 11 | dabat
# Processing Record 39 of Set 11 | del rio
# Processing Record 40 of Set 11 | taksimo
# Processing Record 41 of Set 11 | miandrivazo
# Processing Record 42 of Set 11 | amga
# Processing Record 43 of Set 11 | sistranda
# Processing Record 44 of Set 11 | mlonggo
# Processing Record 45 of Set 11 | alice springs
# Processing Record 46 of Set 11 | kilindoni
# Processing Record 47 of Set 11 | santa cruz
# Processing Record 48 of Set 11 | lyangasovo
# Processing Record 49 of Set 11 | baie-comeau
# Processing Record 50 of Set 11 | upata
# Processing Record 1 of Set 12 | pak phanang
# Processing Record 2 of Set 12 | upington
# Processing Record 3 of Set 12 | nizhniy odes
# Processing Record 4 of Set 12 | shu
# Processing Record 5 of Set 12 | vao
# Processing Record 6 of Set 12 | naze
# Processing Record 7 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 12 | quecholac
# Processing Record 9 of Set 12 | ust-nera
# Processing Record 10 of Set 12 | fairbanks
# Processing Record 11 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 12 | kushima
# Processing Record 13 of Set 12 | tazovskiy
# Processing Record 14 of Set 12 | aljezur
# Processing Record 15 of Set 12 | le francois
# Processing Record 16 of Set 12 | ocos
# Processing Record 17 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 18 of Set 12 | christchurch
# Processing Record 19 of Set 12 | tuatapere
# Processing Record 20 of Set 12 | port blair
# Processing Record 21 of Set 12 | honningsvag
# Processing Record 22 of Set 12 | iqaluit
# Processing Record 23 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 24 of Set 12 | mushie
# Processing Record 25 of Set 12 | chase
# Processing Record 26 of Set 12 | pandan niog
# Processing Record 27 of Set 12 | bezhetsk
# Processing Record 28 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 12 | lac du bonnet
# Processing Record 30 of Set 12 | pontes e lacerda
# Processing Record 31 of Set 12 | valreas
# Processing Record 32 of Set 12 | seoul
# Processing Record 33 of Set 12 | mahon
# Processing Record 34 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 12 | shimoda
# Processing Record 36 of Set 12 | bekhtery
# Processing Record 37 of Set 12 | jimo
# Processing Record 38 of Set 12 | bida
# Processing Record 39 of Set 12 | japura
# Processing Record 40 of Set 12 | messina
# Processing Record 41 of Set 12 | niamey
# Processing Record 42 of Set 12 | impfondo
# Processing Record 43 of Set 12 | zhoucheng
# Processing Record 44 of Set 12 | la rioja
# Processing Record 45 of Set 12 | tura
# Processing Record 46 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 47 of Set 12 | fortuna
# Processing Record 48 of Set 12 | novobirilyussy
# Processing Record 49 of Set 12 | timmins
# Processing Record 50 of Set 12 | pandan
# Processing Record 1 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 13 | mount isa
# ------------------------------------------------
# Data Retrieval Complete
# ------------------------------------------------

# %%
len(lat)
len(temp)
# Out:
# 602

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert raw data to dataframe.
city_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# Drop any cities that were skipped because they could not be found using the OpenWeatherMap API.
city_weather_df = city_weather_df.dropna(how="any")
print(city_weather_df.count())
# Out:
# City          549
# Lat           549
# lng           549
# Max Temp      549
# Humidity      549
# Cloudiness    549
# Wind Speed    549
# Country       549
# Date          549
# dtype: int64

# %%
# Export the city data into a .csv file.
city_weather_df.to_csv("./output_data/city_weather_data.csv", index=False)

# Display the DataFrame
weather_df = pd.read_csv("./output_data/city_weather_data.csv")

weather_df.head()
# Out:
#            City    Lat    lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       ushuaia -54.80 -68.30     37.40      86.0        90.0        2.24
# 1       margate  51.38   1.39     62.01      70.0         0.0        4.00
# 2        bermeo  43.42  -2.72     66.99      82.0        40.0        4.70
# 3  kruisfontein -34.00  24.73     62.85      31.0         0.0       12.37
# 4    sao filipe  14.90 -24.50     77.22      76.0        21.0       10.31
#
#   Country          Date
# 0      AR  1.592595e+09
# 1      GB  1.592595e+09
# 2      ES  1.592596e+09
# 3      ZA  1.592596e+09
# 4      CV  1.592596e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# This section is skiped Because no cities that have humidity > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date_time = datetime.date(datetime.now())
# Create a scatter plot for latitude vs max temperature.
x_values = weather_df['Lat']
y_values = weather_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"City Latitude vs Max Temperature {date_time}")
plt.grid()
plt.savefig("./output_data/latitude_vs_temperature.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude vs humidity.
x_values = weather_df['Lat']
y_values = weather_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(10, 8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity {date_time}')
plt.grid()
plt.savefig("./output_data/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs cloudiness.
x_values = weather_df['Lat']
y_values = weather_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness {date_time}')
plt.grid()
plt.savefig("./output_data/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.
x_values = weather_df['Lat']
y_values = weather_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed {date_time}')
plt.grid()
plt.savefig("./output_data/latitude_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def createLinearRegressionPlot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    fig1, ax1 = plt.subplots(figsize=(10,8))
    plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
    plt.xlabel(x_label,fontsize = 14)
    plt.ylabel(y_label,fontsize = 14)
    if ylim is not None:
        plt.ylim(0, ylim)
    today = datetime.date(datetime.now())
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} {today}",fontsize = 15)
    plt.annotate(line_eq,xy=(10, 50),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-50, 40),fontsize=22,xycoords='data',xytext=(0.4, 0.3), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(10, 25),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    plt.savefig(f"./output_data{hemisphere}_{x_label}_vs_{y_label}.png", bbox_inches="tight")
    return plt.plot(x_values,regress_values,"r-")

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] >= 0]
southern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Max Temp']
createLinearRegressionPlot(x_values, y_values, "Lat", "Max Temp (F)", "Northern",(0, 0))
# Out:
# The r-squared is: 0.45967639893896517
# The correlation between both factors is -0.68

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
# Out:
# The r-squared is: 0.009205210922262086
# The correlation between both factors is -0.1

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(40, 20))
# Out:
# The r-squared is: 0.0035969990298220606
# The correlation between both factors is -0.06

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (southern hemisphere)
x_values1 = southern_hemisphere_weather_df['Lat']
y_values1 = southern_hemisphere_weather_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(40, 20), 150)
# Out:
# The r-squared is: 0.0035969990298220606
# The correlation between both factors is -0.06

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))
# Out:
# The r-squared is: 0.011755946325224193
# The correlation between both factors is -0.11

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
# Out:
# The r-squared is: 0.009205210922262086
# The correlation between both factors is -0.1

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
# Out:
# The r-squared is: 0.005969810771760319
# The correlation between both factors is 0.08

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)
# Out:
# The r-squared is: 0.006159658259569937
# The correlation between both factors is -0.08
